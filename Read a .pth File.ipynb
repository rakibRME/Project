# %% [markdown]
# ## Read a .pth File in PyTorch

# %%
import torch

# Path to your .pth file
path = './checkpoints/miniimagenet/wrn/pt_map_bpa/run_5shot_augFalse_metrics/max_acc.pth'

# Load the checkpoint
checkpoint = torch.load(path, map_location='cpu')

# Show all keys in the state_dict
print("Keys in the checkpoint:")
for k in checkpoint.keys():
    print(k)

# Optional: Inspect one layer's weights
first_key = list(checkpoint.keys())[0]
print(f"\nFirst key: {first_key}")
print("Weights:", checkpoint[first_key])
# Out:
# Keys in the checkpoint:
# conv1.weight
# block1.layer.0.bn1.weight
# block1.layer.0.bn1.bias
# block1.layer.0.bn1.running_mean
# block1.layer.0.bn1.running_var
# block1.layer.0.bn1.num_batches_tracked
# block1.layer.0.conv1.weight
# block1.layer.0.bn2.weight
# block1.layer.0.bn2.bias
# block1.layer.0.bn2.running_mean
# block1.layer.0.bn2.running_var
# block1.layer.0.bn2.num_batches_tracked
# block1.layer.0.conv2.weight
# block1.layer.0.convShortcut.weight
# block1.layer.1.bn1.weight
# block1.layer.1.bn1.bias
# block1.layer.1.bn1.running_mean
# block1.layer.1.bn1.running_var
# block1.layer.1.bn1.num_batches_tracked
# block1.layer.1.conv1.weight
# block1.layer.1.bn2.weight
# block1.layer.1.bn2.bias
# block1.layer.1.bn2.running_mean
# block1.layer.1.bn2.running_var
# block1.layer.1.bn2.num_batches_tracked
# block1.layer.1.conv2.weight
# block1.layer.2.bn1.weight
# block1.layer.2.bn1.bias
# block1.layer.2.bn1.running_mean
# block1.layer.2.bn1.running_var
# block1.layer.2.bn1.num_batches_tracked
# block1.layer.2.conv1.weight
# block1.layer.2.bn2.weight
# block1.layer.2.bn2.bias
# block1.layer.2.bn2.running_mean
# block1.layer.2.bn2.running_var
# block1.layer.2.bn2.num_batches_tracked
# block1.layer.2.conv2.weight
# block1.layer.3.bn1.weight
# block1.layer.3.bn1.bias
# block1.layer.3.bn1.running_mean
# block1.layer.3.bn1.running_var
# block1.layer.3.bn1.num_batches_tracked
# block1.layer.3.conv1.weight
# block1.layer.3.bn2.weight
# block1.layer.3.bn2.bias
# block1.layer.3.bn2.running_mean
# block1.layer.3.bn2.running_var
# block1.layer.3.bn2.num_batches_tracked
# block1.layer.3.conv2.weight
# block2.layer.0.bn1.weight
# block2.layer.0.bn1.bias
# block2.layer.0.bn1.running_mean
# block2.layer.0.bn1.running_var
# block2.layer.0.bn1.num_batches_tracked
# block2.layer.0.conv1.weight
# block2.layer.0.bn2.weight
# block2.layer.0.bn2.bias
# block2.layer.0.bn2.running_mean
# block2.layer.0.bn2.running_var
# block2.layer.0.bn2.num_batches_tracked
# block2.layer.0.conv2.weight
# block2.layer.0.convShortcut.weight
# block2.layer.1.bn1.weight
# block2.layer.1.bn1.bias
# block2.layer.1.bn1.running_mean
# block2.layer.1.bn1.running_var
# block2.layer.1.bn1.num_batches_tracked
# block2.layer.1.conv1.weight
# block2.layer.1.bn2.weight
# block2.layer.1.bn2.bias
# block2.layer.1.bn2.running_mean
# block2.layer.1.bn2.running_var
# block2.layer.1.bn2.num_batches_tracked
# block2.layer.1.conv2.weight
# block2.layer.2.bn1.weight
# block2.layer.2.bn1.bias
# block2.layer.2.bn1.running_mean
# block2.layer.2.bn1.running_var
# block2.layer.2.bn1.num_batches_tracked
# block2.layer.2.conv1.weight
# block2.layer.2.bn2.weight
# block2.layer.2.bn2.bias
# block2.layer.2.bn2.running_mean
# block2.layer.2.bn2.running_var
# block2.layer.2.bn2.num_batches_tracked
# block2.layer.2.conv2.weight
# block2.layer.3.bn1.weight
# block2.layer.3.bn1.bias
# block2.layer.3.bn1.running_mean
# block2.layer.3.bn1.running_var
# block2.layer.3.bn1.num_batches_tracked
# block2.layer.3.conv1.weight
# block2.layer.3.bn2.weight
# block2.layer.3.bn2.bias
# block2.layer.3.bn2.running_mean
# block2.layer.3.bn2.running_var
# block2.layer.3.bn2.num_batches_tracked
# block2.layer.3.conv2.weight
# block3.layer.0.bn1.weight
# block3.layer.0.bn1.bias
# block3.layer.0.bn1.running_mean
# block3.layer.0.bn1.running_var
# block3.layer.0.bn1.num_batches_tracked
# block3.layer.0.conv1.weight
# block3.layer.0.bn2.weight
# block3.layer.0.bn2.bias
# block3.layer.0.bn2.running_mean
# block3.layer.0.bn2.running_var
# block3.layer.0.bn2.num_batches_tracked
# block3.layer.0.conv2.weight
# block3.layer.0.convShortcut.weight
# block3.layer.1.bn1.weight
# block3.layer.1.bn1.bias
# block3.layer.1.bn1.running_mean
# block3.layer.1.bn1.running_var
# block3.layer.1.bn1.num_batches_tracked
# block3.layer.1.conv1.weight
# block3.layer.1.bn2.weight
# block3.layer.1.bn2.bias
# block3.layer.1.bn2.running_mean
# block3.layer.1.bn2.running_var
# block3.layer.1.bn2.num_batches_tracked
# block3.layer.1.conv2.weight
# block3.layer.2.bn1.weight
# block3.layer.2.bn1.bias
# block3.layer.2.bn1.running_mean
# block3.layer.2.bn1.running_var
# block3.layer.2.bn1.num_batches_tracked
# block3.layer.2.conv1.weight
# block3.layer.2.bn2.weight
# block3.layer.2.bn2.bias
# block3.layer.2.bn2.running_mean
# block3.layer.2.bn2.running_var
# block3.layer.2.bn2.num_batches_tracked
# block3.layer.2.conv2.weight
# block3.layer.3.bn1.weight
# block3.layer.3.bn1.bias
# block3.layer.3.bn1.running_mean
# block3.layer.3.bn1.running_var
# block3.layer.3.bn1.num_batches_tracked
# block3.layer.3.conv1.weight
# block3.layer.3.bn2.weight
# block3.layer.3.bn2.bias
# block3.layer.3.bn2.running_mean
# block3.layer.3.bn2.running_var
# block3.layer.3.bn2.num_batches_tracked
# block3.layer.3.conv2.weight
# bn1.weight
# bn1.bias
# bn1.running_mean
# bn1.running_var
# bn1.num_batches_tracked
#
# First key: conv1.weight
# Weights: tensor([[[[-0.0724,  0.1601, -0.0261],
#           [ 0.1092, -0.0453, -0.1113],
#           [-0.0534, -0.1143,  0.2595]],
#
#          [[ 0.0305, -0.1077, -0.1575],
#           [ 0.1095, -0.0782, -0.0660],
#           [-0.1956, -0.0146,  0.0432]],
#
#          [[-0.0029, -0.1076, -0.2314],
#           [-0.1564, -0.1010,  0.0660],
#           [ 0.1995, -0.0129, -0.0386]]],
#
#
#         [[[-0.0833, -0.2719,  0.0064],
#           [ 0.1854, -0.0361,  0.0845],
#           [-0.0647,  0.1000, -0.0267]],
#
#          [[-0.0885, -0.1863,  0.0861],
#           [ 0.1341,  0.0832,  0.1074],
#           [-0.0796,  0.1263,  0.1519]],
#
#          [[ 0.0762,  0.1379, -0.1081],
#           [ 0.0433,  0.0278, -0.0640],
#           [-0.1204, -0.0352, -0.0618]]],
#
#
#         [[[ 0.2579, -0.1732, -0.1144],
#           [ 0.0495,  0.0433,  0.1188],
#           [-0.0662, -0.0773,  0.0225]],
#
#          [[-0.2350, -0.0874, -0.3274],
#           [ 0.1394, -0.0506, -0.0116],
#           [-0.0056,  0.1120,  0.0315]],
#
#          [[ 0.0961,  0.0135, -0.2477],
#           [ 0.1613,  0.0055,  0.0639],
#           [-0.1034,  0.0672,  0.2203]]],
#
#
#         [[[-0.0302, -0.2038,  0.2092],
#           [-0.0258, -0.0773,  0.0596],
#           [ 0.1725, -0.3394,  0.1709]],
#
#          [[ 0.0414, -0.0379,  0.1001],
#           [ 0.0224,  0.1032, -0.1556],
#           [ 0.0386, -0.1560, -0.0379]],
#
#          [[ 0.0901, -0.0680, -0.0630],
#           [-0.2067, -0.0350, -0.0005],
#           [ 0.0853,  0.1239, -0.1636]]],
#
#
#         [[[-0.0356,  0.0020, -0.1077],
#           [ 0.0963,  0.0501,  0.0102],
#           [ 0.1099,  0.1157,  0.1273]],
#
#          [[ 0.0657,  0.2189, -0.1086],
#           [ 0.1271, -0.0550,  0.0724],
#           [ 0.2889, -0.1156,  0.2071]],
#
#          [[ 0.1015,  0.0339, -0.0897],
#           [-0.0470, -0.2746,  0.0178],
#           [-0.0105,  0.1318,  0.0468]]],
#
#
#         [[[-0.0095, -0.1331,  0.1077],
#           [-0.0901, -0.1017,  0.0021],
#           [ 0.0399,  0.0608, -0.0262]],
#
#          [[ 0.0819, -0.1801,  0.0992],
#           [-0.0216,  0.1949, -0.0114],
#           [ 0.2696, -0.0788,  0.0750]],
#
#          [[ 0.1208, -0.3081,  0.1348],
#           [-0.0771,  0.0407, -0.1340],
#           [ 0.0416,  0.0269, -0.1795]]],
#
#
#         [[[ 0.0176, -0.1629, -0.1365],
#           [-0.0240, -0.0786,  0.2060],
#           [-0.0516, -0.0223, -0.1159]],
#
#          [[-0.0203,  0.0247,  0.1713],
#           [ 0.0674,  0.0446, -0.1194],
#           [-0.0192,  0.1790,  0.0701]],
#
#          [[-0.0400, -0.0101,  0.0497],
#           [-0.0907, -0.1471,  0.0893],
#           [ 0.0320, -0.0081,  0.0366]]],
#
#
#         [[[-0.0467,  0.0246,  0.1974],
#           [ 0.2002,  0.0808, -0.0238],
#           [-0.1236, -0.0071, -0.0385]],
#
#          [[ 0.0526, -0.1503,  0.1100],
#           [ 0.2416, -0.0066,  0.0572],
#           [ 0.0826, -0.0202,  0.0775]],
#
#          [[-0.1019,  0.1648,  0.1394],
#           [ 0.0455,  0.1413, -0.0933],
#           [ 0.0711, -0.0429, -0.0370]]],
#
#
#         [[[-0.0577, -0.0929, -0.0192],
#           [ 0.2230, -0.2574, -0.0673],
#           [ 0.0058, -0.2309, -0.0417]],
#
#          [[-0.0571, -0.1280,  0.1748],
#           [ 0.1421,  0.0082,  0.0413],
#           [-0.2294, -0.2064,  0.1261]],
#
#          [[-0.0099,  0.0702,  0.0105],
#           [-0.2440,  0.2645, -0.0291],
#           [ 0.0746,  0.1776, -0.0479]]],
#
#
#         [[[ 0.0427, -0.0327,  0.0506],
#           [-0.0139, -0.0301,  0.0109],
#           [-0.0184,  0.1333, -0.0704]],
#
#          [[ 0.1623, -0.0259,  0.1131],
#           [ 0.1541, -0.1964, -0.0405],
#           [-0.2278,  0.0723, -0.1289]],
#
#          [[ 0.0314, -0.1162, -0.1102],
#           [ 0.2365,  0.0402, -0.0075],
#           [ 0.0620, -0.0265, -0.0626]]],
#
#
#         [[[ 0.1480, -0.1360, -0.1614],
#           [ 0.0120, -0.1924, -0.0876],
#           [-0.0357, -0.3084,  0.0114]],
#
#          [[-0.1368,  0.0347, -0.1015],
#           [ 0.2542,  0.0143,  0.0178],
#           [-0.0292, -0.0646,  0.0715]],
#
#          [[ 0.1655,  0.0763,  0.0722],
#           [ 0.0070,  0.0472, -0.0525],
#           [ 0.0879,  0.0843,  0.0206]]],
#
#
#         [[[-0.1003, -0.0013,  0.0022],
#           [ 0.0372,  0.1020, -0.0308],
#           [-0.0257, -0.0649, -0.1061]],
#
#          [[-0.3736,  0.2349,  0.0760],
#           [-0.0829, -0.1057, -0.0689],
#           [-0.0815, -0.0929, -0.0637]],
#
#          [[-0.0864,  0.0858,  0.0167],
#           [-0.0366,  0.0580, -0.0411],
#           [ 0.0837, -0.2341,  0.0910]]],
#
#
#         [[[ 0.0018,  0.3053, -0.1750],
#           [ 0.1867,  0.0072, -0.0290],
#           [ 0.0937, -0.0976,  0.0099]],
#
#          [[ 0.0414,  0.1788,  0.0313],
#           [ 0.0044, -0.1357,  0.0177],
#           [ 0.1977, -0.1735,  0.1703]],
#
#          [[-0.1807, -0.2380,  0.0455],
#           [-0.1103,  0.1733, -0.0598],
#           [-0.0042, -0.0141, -0.0822]]],
#
#
#         [[[ 0.0212, -0.0958, -0.0086],
#           [ 0.0150, -0.1598,  0.0042],
#           [-0.1709,  0.0070, -0.0490]],
#
#          [[ 0.0138,  0.1597, -0.1040],
#           [ 0.0223,  0.0421,  0.0768],
#           [ 0.0480, -0.2086, -0.1095]],
#
#          [[-0.1224, -0.2786, -0.0504],
#           [-0.0728,  0.0406,  0.1978],
#           [-0.2303,  0.1205,  0.0305]]],
#
#
#         [[[-0.1547,  0.0474, -0.0669],
#           [-0.1577,  0.1158, -0.1290],
#           [ 0.0425, -0.0070,  0.0215]],
#
#          [[ 0.1366,  0.2396,  0.0751],
#           [-0.2012,  0.0570, -0.2856],
#           [ 0.0347,  0.1837, -0.1375]],
#
#          [[-0.0155, -0.0514,  0.2401],
#           [-0.2208,  0.0348,  0.1697],
#           [-0.1427,  0.0058,  0.1702]]],
#
#
#         [[[ 0.1179,  0.0460, -0.0421],
#           [-0.1355,  0.0044, -0.2149],
#           [-0.1565, -0.0227, -0.1790]],
#
#          [[-0.0287, -0.0619,  0.0355],
#           [ 0.1396,  0.0111,  0.0926],
#           [-0.0213,  0.0776, -0.0939]],
#
#          [[ 0.0716,  0.2145, -0.1270],
#           [-0.1819,  0.1472,  0.0867],
#           [-0.3519,  0.1245, -0.0749]]]])

# %% [markdown]
# ## All Layers and Their Shapes

# %%
for key, value in checkpoint.items():
    print(f"{key} -> shape: {value.shape}")
# Out:
# conv1.weight -> shape: torch.Size([16, 3, 3, 3])
# block1.layer.0.bn1.weight -> shape: torch.Size([16])
# block1.layer.0.bn1.bias -> shape: torch.Size([16])
# block1.layer.0.bn1.running_mean -> shape: torch.Size([16])
# block1.layer.0.bn1.running_var -> shape: torch.Size([16])
# block1.layer.0.bn1.num_batches_tracked -> shape: torch.Size([])
# block1.layer.0.conv1.weight -> shape: torch.Size([160, 16, 3, 3])
# block1.layer.0.bn2.weight -> shape: torch.Size([160])
# block1.layer.0.bn2.bias -> shape: torch.Size([160])
# block1.layer.0.bn2.running_mean -> shape: torch.Size([160])
# block1.layer.0.bn2.running_var -> shape: torch.Size([160])
# block1.layer.0.bn2.num_batches_tracked -> shape: torch.Size([])
# block1.layer.0.conv2.weight -> shape: torch.Size([160, 160, 3, 3])
# block1.layer.0.convShortcut.weight -> shape: torch.Size([160, 16, 1, 1])
# block1.layer.1.bn1.weight -> shape: torch.Size([160])
# block1.layer.1.bn1.bias -> shape: torch.Size([160])
# block1.layer.1.bn1.running_mean -> shape: torch.Size([160])
# block1.layer.1.bn1.running_var -> shape: torch.Size([160])
# block1.layer.1.bn1.num_batches_tracked -> shape: torch.Size([])
# block1.layer.1.conv1.weight -> shape: torch.Size([160, 160, 3, 3])
# block1.layer.1.bn2.weight -> shape: torch.Size([160])
# block1.layer.1.bn2.bias -> shape: torch.Size([160])
# block1.layer.1.bn2.running_mean -> shape: torch.Size([160])
# block1.layer.1.bn2.running_var -> shape: torch.Size([160])
# block1.layer.1.bn2.num_batches_tracked -> shape: torch.Size([])
# block1.layer.1.conv2.weight -> shape: torch.Size([160, 160, 3, 3])
# block1.layer.2.bn1.weight -> shape: torch.Size([160])
# block1.layer.2.bn1.bias -> shape: torch.Size([160])
# block1.layer.2.bn1.running_mean -> shape: torch.Size([160])
# block1.layer.2.bn1.running_var -> shape: torch.Size([160])
# block1.layer.2.bn1.num_batches_tracked -> shape: torch.Size([])
# block1.layer.2.conv1.weight -> shape: torch.Size([160, 160, 3, 3])
# block1.layer.2.bn2.weight -> shape: torch.Size([160])
# block1.layer.2.bn2.bias -> shape: torch.Size([160])
# block1.layer.2.bn2.running_mean -> shape: torch.Size([160])
# block1.layer.2.bn2.running_var -> shape: torch.Size([160])
# block1.layer.2.bn2.num_batches_tracked -> shape: torch.Size([])
# block1.layer.2.conv2.weight -> shape: torch.Size([160, 160, 3, 3])
# block1.layer.3.bn1.weight -> shape: torch.Size([160])
# block1.layer.3.bn1.bias -> shape: torch.Size([160])
# block1.layer.3.bn1.running_mean -> shape: torch.Size([160])
# block1.layer.3.bn1.running_var -> shape: torch.Size([160])
# block1.layer.3.bn1.num_batches_tracked -> shape: torch.Size([])
# block1.layer.3.conv1.weight -> shape: torch.Size([160, 160, 3, 3])
# block1.layer.3.bn2.weight -> shape: torch.Size([160])
# block1.layer.3.bn2.bias -> shape: torch.Size([160])
# block1.layer.3.bn2.running_mean -> shape: torch.Size([160])
# block1.layer.3.bn2.running_var -> shape: torch.Size([160])
# block1.layer.3.bn2.num_batches_tracked -> shape: torch.Size([])
# block1.layer.3.conv2.weight -> shape: torch.Size([160, 160, 3, 3])
# block2.layer.0.bn1.weight -> shape: torch.Size([160])
# block2.layer.0.bn1.bias -> shape: torch.Size([160])
# block2.layer.0.bn1.running_mean -> shape: torch.Size([160])
# block2.layer.0.bn1.running_var -> shape: torch.Size([160])
# block2.layer.0.bn1.num_batches_tracked -> shape: torch.Size([])
# block2.layer.0.conv1.weight -> shape: torch.Size([320, 160, 3, 3])
# block2.layer.0.bn2.weight -> shape: torch.Size([320])
# block2.layer.0.bn2.bias -> shape: torch.Size([320])
# block2.layer.0.bn2.running_mean -> shape: torch.Size([320])
# block2.layer.0.bn2.running_var -> shape: torch.Size([320])
# block2.layer.0.bn2.num_batches_tracked -> shape: torch.Size([])
# block2.layer.0.conv2.weight -> shape: torch.Size([320, 320, 3, 3])
# block2.layer.0.convShortcut.weight -> shape: torch.Size([320, 160, 1, 1])
# block2.layer.1.bn1.weight -> shape: torch.Size([320])
# block2.layer.1.bn1.bias -> shape: torch.Size([320])
# block2.layer.1.bn1.running_mean -> shape: torch.Size([320])
# block2.layer.1.bn1.running_var -> shape: torch.Size([320])
# block2.layer.1.bn1.num_batches_tracked -> shape: torch.Size([])
# block2.layer.1.conv1.weight -> shape: torch.Size([320, 320, 3, 3])
# block2.layer.1.bn2.weight -> shape: torch.Size([320])
# block2.layer.1.bn2.bias -> shape: torch.Size([320])
# block2.layer.1.bn2.running_mean -> shape: torch.Size([320])
# block2.layer.1.bn2.running_var -> shape: torch.Size([320])
# block2.layer.1.bn2.num_batches_tracked -> shape: torch.Size([])
# block2.layer.1.conv2.weight -> shape: torch.Size([320, 320, 3, 3])
# block2.layer.2.bn1.weight -> shape: torch.Size([320])
# block2.layer.2.bn1.bias -> shape: torch.Size([320])
# block2.layer.2.bn1.running_mean -> shape: torch.Size([320])
# block2.layer.2.bn1.running_var -> shape: torch.Size([320])
# block2.layer.2.bn1.num_batches_tracked -> shape: torch.Size([])
# block2.layer.2.conv1.weight -> shape: torch.Size([320, 320, 3, 3])
# block2.layer.2.bn2.weight -> shape: torch.Size([320])
# block2.layer.2.bn2.bias -> shape: torch.Size([320])
# block2.layer.2.bn2.running_mean -> shape: torch.Size([320])
# block2.layer.2.bn2.running_var -> shape: torch.Size([320])
# block2.layer.2.bn2.num_batches_tracked -> shape: torch.Size([])
# block2.layer.2.conv2.weight -> shape: torch.Size([320, 320, 3, 3])
# block2.layer.3.bn1.weight -> shape: torch.Size([320])
# block2.layer.3.bn1.bias -> shape: torch.Size([320])
# block2.layer.3.bn1.running_mean -> shape: torch.Size([320])
# block2.layer.3.bn1.running_var -> shape: torch.Size([320])
# block2.layer.3.bn1.num_batches_tracked -> shape: torch.Size([])
# block2.layer.3.conv1.weight -> shape: torch.Size([320, 320, 3, 3])
# block2.layer.3.bn2.weight -> shape: torch.Size([320])
# block2.layer.3.bn2.bias -> shape: torch.Size([320])
# block2.layer.3.bn2.running_mean -> shape: torch.Size([320])
# block2.layer.3.bn2.running_var -> shape: torch.Size([320])
# block2.layer.3.bn2.num_batches_tracked -> shape: torch.Size([])
# block2.layer.3.conv2.weight -> shape: torch.Size([320, 320, 3, 3])
# block3.layer.0.bn1.weight -> shape: torch.Size([320])
# block3.layer.0.bn1.bias -> shape: torch.Size([320])
# block3.layer.0.bn1.running_mean -> shape: torch.Size([320])
# block3.layer.0.bn1.running_var -> shape: torch.Size([320])
# block3.layer.0.bn1.num_batches_tracked -> shape: torch.Size([])
# block3.layer.0.conv1.weight -> shape: torch.Size([640, 320, 3, 3])
# block3.layer.0.bn2.weight -> shape: torch.Size([640])
# block3.layer.0.bn2.bias -> shape: torch.Size([640])
# block3.layer.0.bn2.running_mean -> shape: torch.Size([640])
# block3.layer.0.bn2.running_var -> shape: torch.Size([640])
# block3.layer.0.bn2.num_batches_tracked -> shape: torch.Size([])
# block3.layer.0.conv2.weight -> shape: torch.Size([640, 640, 3, 3])
# block3.layer.0.convShortcut.weight -> shape: torch.Size([640, 320, 1, 1])
# block3.layer.1.bn1.weight -> shape: torch.Size([640])
# block3.layer.1.bn1.bias -> shape: torch.Size([640])
# block3.layer.1.bn1.running_mean -> shape: torch.Size([640])
# block3.layer.1.bn1.running_var -> shape: torch.Size([640])
# block3.layer.1.bn1.num_batches_tracked -> shape: torch.Size([])
# block3.layer.1.conv1.weight -> shape: torch.Size([640, 640, 3, 3])
# block3.layer.1.bn2.weight -> shape: torch.Size([640])
# block3.layer.1.bn2.bias -> shape: torch.Size([640])
# block3.layer.1.bn2.running_mean -> shape: torch.Size([640])
# block3.layer.1.bn2.running_var -> shape: torch.Size([640])
# block3.layer.1.bn2.num_batches_tracked -> shape: torch.Size([])
# block3.layer.1.conv2.weight -> shape: torch.Size([640, 640, 3, 3])
# block3.layer.2.bn1.weight -> shape: torch.Size([640])
# block3.layer.2.bn1.bias -> shape: torch.Size([640])
# block3.layer.2.bn1.running_mean -> shape: torch.Size([640])
# block3.layer.2.bn1.running_var -> shape: torch.Size([640])
# block3.layer.2.bn1.num_batches_tracked -> shape: torch.Size([])
# block3.layer.2.conv1.weight -> shape: torch.Size([640, 640, 3, 3])
# block3.layer.2.bn2.weight -> shape: torch.Size([640])
# block3.layer.2.bn2.bias -> shape: torch.Size([640])
# block3.layer.2.bn2.running_mean -> shape: torch.Size([640])
# block3.layer.2.bn2.running_var -> shape: torch.Size([640])
# block3.layer.2.bn2.num_batches_tracked -> shape: torch.Size([])
# block3.layer.2.conv2.weight -> shape: torch.Size([640, 640, 3, 3])
# block3.layer.3.bn1.weight -> shape: torch.Size([640])
# block3.layer.3.bn1.bias -> shape: torch.Size([640])
# block3.layer.3.bn1.running_mean -> shape: torch.Size([640])
# block3.layer.3.bn1.running_var -> shape: torch.Size([640])
# block3.layer.3.bn1.num_batches_tracked -> shape: torch.Size([])
# block3.layer.3.conv1.weight -> shape: torch.Size([640, 640, 3, 3])
# block3.layer.3.bn2.weight -> shape: torch.Size([640])
# block3.layer.3.bn2.bias -> shape: torch.Size([640])
# block3.layer.3.bn2.running_mean -> shape: torch.Size([640])
# block3.layer.3.bn2.running_var -> shape: torch.Size([640])
# block3.layer.3.bn2.num_batches_tracked -> shape: torch.Size([])
# block3.layer.3.conv2.weight -> shape: torch.Size([640, 640, 3, 3])
# bn1.weight -> shape: torch.Size([640])
# bn1.bias -> shape: torch.Size([640])
# bn1.running_mean -> shape: torch.Size([640])
# bn1.running_var -> shape: torch.Size([640])
# bn1.num_batches_tracked -> shape: torch.Size([])

# %% [markdown]
# ## How many parameters?

# %%
import torch

# Load checkpoint
path = './checkpoints/miniimagenet/wrn/pt_map_bpa/run_5shot_augFalse_metrics/max_acc.pth'
checkpoint = torch.load(path, map_location='cpu')

# Sometimes weights are under 'state_dict', sometimes not
state_dict = checkpoint.get('state_dict', checkpoint)

# Count total parameters
total_params = sum(v.numel() for v in state_dict.values())
print(f"Total parameters: {total_params:,}")
# Out:
# Total parameters: 36,490,761
