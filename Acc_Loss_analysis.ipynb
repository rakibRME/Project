# %% [markdown]
# ## run_5shot_augFalse_metrics

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/rmedu-4090/rkb/BPA/checkpoints/miniimagenet/wrn/pt_map_bpa/run_5shot_augFalse_metrics/metrics.csv')
plt.plot(df['epoch'], df['train_loss'], label='Train Loss')
plt.plot(df['epoch'], df['val_loss'], label='Val Loss')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/rmedu-4090/rkb/BPA/checkpoints/miniimagenet/wrn/pt_map_bpa/run_5shot_augFalse_metrics/metrics.csv')
plt.plot(df['epoch'], df['train_acc'], label='Train Acc')
plt.plot(df['epoch'], df['val_acc'], label='Val Acc')
plt.legend()
plt.show()

# %% [markdown]
# ## run_1shot_augFalse_metrics

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/rmedu-4090/rkb/BPA/checkpoints/miniimagenet/wrn/pt_map_bpa/run_1shot_augFalse_metrics/metrics.csv')
plt.plot(df['epoch'], df['train_loss'], label='Train Loss')
plt.plot(df['epoch'], df['val_loss'], label='Val Loss')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/rmedu-4090/rkb/BPA/checkpoints/miniimagenet/wrn/pt_map_bpa/run_1shot_augFalse_metrics/metrics.csv')
plt.plot(df['epoch'], df['train_acc'], label='Train Acc')
plt.plot(df['epoch'], df['val_acc'], label='Val Acc')
plt.legend()
plt.show()
